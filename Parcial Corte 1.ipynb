# %% [markdown]
# # Parcial corte 2
# * Daniel Steven Vargas Guzmán [dsvargas@unbosque.edu.co](mailto://dsvargas@unbosque.edu.co)
# *15 de Febrero del 2021

# %% [markdown]
# #### 1. Explique, en sus propias palabras, qué relación existe entre Anaconda y Python, al igual que sus principales diferencias. Sea lo más preciso posible.
#
# Anaconda es una distribución que esta enfocada a la ciencia de datos, por otro lado, python es el lenguaje de programación especificamente de alto nivel

# %% [markdown]
# #### 2. Explique, en sus propias palabras, qué es un ambiente virtual de python, y qué ventajas puede haber al hacer uso de éstos. Válgase de diagramas o ilustraciones hechas por usted mismo, para complementar su explicación.
#
# Un ambiente virtual de python corresponde a una sección contenida de python dispuesta para hacer ambientes de trabajo independientes, es decir, ambientes cuya ambiente tiene un directorio especifico de trabajo, una de sus ventajas es poder disponer de diferentes versiones de python que se requiera, implicando la creación de diferentes escenarios de trabajo con diferentes versiones y librerias para la implementación de desarrollos que no esten soportodas en otras versiones
#
# Diagrama de ambientes virtuales de python:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. Explique, en sus propias palabras, qué diferencias hay entre los manejadores de paquetes pip y conda. Mencione en qué casos debemos utilizar uno o el otro, y dé algunos ejemplos del uso de cada uno, de acuerdo con su respuesta.
#
# #### PIP:
# la descripción de pip es la instalación de paquetes dispuestos para librerias de python de manera oficial, además de la implementación de paquetes locales, este si verifica las dependencias de los paquetes instalados, la sintaxis de este corresponde a: $>pip install <paquete>
#
# #### Conda
#
# Conda por su parte permite instalar paquetes externos a pip, tales como R, RStudio, Visual Studio Code y GDAL, a diferencia de PIP, este comando si verifica las dependencias de estos paquetes, además de la creación de los diferentes ambientes de python
# La sintaxis de este corresponde a: conda create -n -ambiente-
#
# Su principal diferencia es que Conda permite la gestión de ambientes de trabajo en python y por su parte pip la implementación de paquetes principalmente para librerias de python dentro del ambiente de trabajo que se crea con conda

# %% [markdown]
# #### 4. Explique, en sus propias palabras, qué es Jupyter Notebooks, para que son útiles estos  tipos de documentos, y su relación con el análisis de datos reproducible. Elabore sobre la importancia del análisis de datos reproducible.
#
# Jupyther notebook es un cuaderno de trabajo dispuesto para la ejecución de manera dinámica el lenguaje de programación python como si fuera un informe de trabajo, en este caso con respecto al análisis de datos reproducible, se puede hacer la ejecución de código con ArcPy y R usando Jupyter Notebook, como se puede demostrar en la siguiente imagen:
#
# Su importancia es la gestión y de visualizaciónd de datos de forma accesible y de fácil uso para su implementación, contrastando información relevante sobre diagramas o gráficos que permiten el análisis de dichos datos
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 5. Explique, en sus propias palabras, qué es Markdown, y qué utilidad tiene a la hora de ser usado dentro de un documento de Jupyter Notebooks. Sea lo más específico posible
#
#
# La implementación de celdas markdown permite la creación de texto dentro del cuaderno de trabajo, siendo desde Collab o Jupyter, la utilidad de este consta de la producción de cadenas de texto, titulos, indices, formulas, envio a un destinatario de correo, entre otras funciones, este se comporta de tal forma que se evidencia a modo de documento con indicaciones, explicación, comentarios..etc.

# %% [markdown]
# #### 6. Explique, en sus propias palabras, qué es LaTeX, y qué utilidad tiene a la hora de ser usado dentro de un documento de Jupyter Notebooks. Provea un ejemplo concreto, de forma breve que ejemplifique dicha utilidad.
#
#
# LaTeX  es un sistema de composición de textos el cual permite la creacipon de formulas de forma organizada, legible a partir de sentencias especificas de la reproducción de la formula en una celda de markdown, dentro del documento de Jupyter es escencial a la hora de expresar formulas complejas, de tal forma que se evidencia no a manera de texto sino de forma gráfica.
#
# Ejemplo de formula:
# $$\text{La Fórmula Cuadrática es }x = \frac {-b \pm \sqrt {b^2 - 4ac}}{2a}$$

# %% [markdown]
# #### 7. Explique, en sus propias palabras, qué diferencias existen entre una variable y una constante en Python, según las convenciones establecidas para el uso del lenguaje. ¿Qué implicaciones prácticas tiene esto a la hora de definir una constante en Python? Demuéstrelas con un ejemplo breve.
#
# las constantes en python generalmente tienen una sintaxis que las identifica como una constante, esta constante no puede ser modificada en su implementación o uso, de manera que las variables por el lado contrario si pueden ser modificadas
#
# un claro ejemplo seria la conexión para una base de datos, que se manejan como constantes con esta información:
#
# ```Python
# PORT_DB_SERVER = 5432
# USER_DB_SERVER = "root"
# PASSWORD_DB_SERVER = "123456"
# DB_NAME = "db"
# ```

# %% [markdown]
# #### 8. En una celda de Markdown con un bloque de código, muestre la función para calcular la serie de Fibonacci en otro lenguaje que no sea Python
# ```Java
# // https://elvex.ugr.es/decsai/java/pdf/7C-Ejemplos.pdf
# public static int fibonacci (int n) \n
# {
#  if ((n == 0) || (n == 1))
#  return 1;
#  else
#  return fibonacci(n-1) + fibonacci(n-2);
# }
# ```

# %% [markdown]
# #### 9. En una celda de Markdown, escriba el código necesario de LaTeX para reproducir la formula
# $$
# Cov (Q_1,Q_2) = Cov \left(\sum_{i=1}^{V_1} Z_{1,i}^{2},\sum_{j=1}^{V_2} Z_{2.j}^{2}\right)
# = \sum_{i=1}^{V_1}\sum_{j=1}^{V_2} Cov(Z_{1,i}^{2} , Z_{2.j}^{2}) = 2 \sum_{i=1}^{V_1}\sum_{j=1}^{V_2}
# \rho^{2} (Z_{1,i} , Z_{2.j}) \geq 0.
# $$

# %%
# 10.1  Defina la constante ( ) Pi con al menos 6 lugares decimales

import math
PI = math.pi
print(PI)
# Out:
# 3.141592653589793

# %%
# 10.2. Defina una lista con 10 tuplas distintas, correspondientes a 10 combinaciones de radios
import numpy as np
from numpy import array

n = [[3,5],[6,7],[9,7],[9,8],[8,9],[2,5],[6,5],[7,8],[8,7],[9,9]]

print(n)
# Out:
# [[3, 5], [6, 7], [9, 7], [9, 8], [8, 9], [2, 5], [6, 5], [7, 8], [8, 7], [9, 9]]

# %%
#10.3. Cree un diccionario vacío donde almacenar sus resultados

diccionario = {}

# %%
# 10.4 Defina una función para calcular el volumen de un cono, que reciba como argumento 
# una tupla que contiene un radio y una altura, y retorne el resultado del cálculo
def calcularVolumenCono(n):
    for i in range(len(n)):
        var = (1/3)*PI*math.pow(n[i][0],2)*n[i][1]
        print("El volumen del cono de radio: ", n[i][0], " con una altura de: ", n[i][1], ' es de: ', var)              

calcularVolumenCono(n)
# Out:
# El volumen del cono de radio:  3  con una altura de:  5  es de:  47.12388980384689
# El volumen del cono de radio:  6  con una altura de:  7  es de:  263.89378290154264
# El volumen del cono de radio:  9  con una altura de:  7  es de:  593.7610115284708
# El volumen del cono de radio:  9  con una altura de:  8  es de:  678.5840131753953
# El volumen del cono de radio:  8  con una altura de:  9  es de:  603.1857894892403
# El volumen del cono de radio:  2  con una altura de:  5  es de:  20.94395102393195
# El volumen del cono de radio:  6  con una altura de:  5  es de:  188.49555921538757
# El volumen del cono de radio:  7  con una altura de:  8  es de:  410.5014400690663
# El volumen del cono de radio:  8  con una altura de:  7  es de:  469.14450293607575
# El volumen del cono de radio:  9  con una altura de:  9  es de:  763.4070148223198

# %%
# 10.5. Haciendo uso de estructuras de control en Python, escriba un programa que por cada
# uno de las tuplas en la lista, calcule el volumen del cono, y guarde los resultados en el
# diccionario de salida; las llaves del diccionario deben ser las tuplas de cada
# círculo/altura, y cada valor será el volumen que les corresponde.
diccinarioSalida = {}
m = list()
def calcularVolumenCono():
    for i in range(len(n)):
        cadena = "[" + str(n[i][0]) + ',' + str(n[i][1]) + ']'
        m.append(cadena)
        
    for j in range(len(m)):
        var = (1/3)*PI*math.pow(n[i][0],2)*n[i][1]
        diccinarioSalida[m[j]] = var
    print(diccinarioSalida)

        
calcularVolumenCono()
# Out:
# {'[3,5]': 763.4070148223198, '[6,7]': 763.4070148223198, '[9,7]': 763.4070148223198, '[9,8]': 763.4070148223198, '[8,9]': 763.4070148223198, '[2,5]': 763.4070148223198, '[6,5]': 763.4070148223198, '[7,8]': 763.4070148223198, '[8,7]': 763.4070148223198, '[9,9]': 763.4070148223198}

# %%
#6. Por cada uno de los ítems del diccionario, imprima el radio, la altura y su volumen
#correspondiente.

for key in diccinarioSalida.keys():
    print('(radio,altura): ', key, '--- volumen: ', diccinarioSalida[key])
# Out:
# (radio,altura):  [3,5] --- volumen:  763.4070148223198
# (radio,altura):  [6,7] --- volumen:  763.4070148223198
# (radio,altura):  [9,7] --- volumen:  763.4070148223198
# (radio,altura):  [9,8] --- volumen:  763.4070148223198
# (radio,altura):  [8,9] --- volumen:  763.4070148223198
# (radio,altura):  [2,5] --- volumen:  763.4070148223198
# (radio,altura):  [6,5] --- volumen:  763.4070148223198
# (radio,altura):  [7,8] --- volumen:  763.4070148223198
# (radio,altura):  [8,7] --- volumen:  763.4070148223198
# (radio,altura):  [9,9] --- volumen:  763.4070148223198

# %%
#11. Asuma que U es un arreglo unidimensional. Construya una función que genere a partir de
#    U, otro arreglo V, el cual contenga la misma cantidad de valores que U, definidos como:

u = [1,3,5,7,9,8,6,4,2,0]
v = []
def ContruirV():
    for i in range(len(u)):
        try:
            valor = (u[i-2] + u[i-1] + u[i] + u[i+1])/4
            v.append(valor)
        except:
            print('Fuera del indice del array')
            v.append(0)


ContruirV()
print(v)
# Out:
# Fuera del indice del array
# [1.5, 2.25, 4.0, 6.0, 7.25, 7.5, 6.75, 5.0, 3.0, 0]

# %%
#12. Importe el archivo Datos_Parcial1.dat (valores separados por comas) como un objeto
# de tipo lista

a = np.fromfile('Datos_Parcial1.dat', dtype=np.int, sep=',')
print(a)
# Out:
# [  0  27  54  81 108 135 162 189 216 243 270 297 324 351 378 405 432 459
#  486 513 540 567 594 621]

# %%
#12.1 ¿Cuántos elementos tiene la lista? Demuestre su respuesta.
print('La cantidad de lementos de la lista son: ',len(a))

#Teniendo en cuenta que la función len(a), retorna la cantidad de elementos que se almacena en el arreglo
# Out:
# La cantidad de lementos de la lista son:  24

# %%
#12.2 ¿De qué tipo son los elementos contenidos en la lista? Demuestre su respuesta.
print('El tipo de elementos que se contienen en la lista corresponden al tipo: ',a.dtype)

#el resultado que retorna la propieda de a.dtype corresponde a el tipo de arreglo al que corresponde (a), es decir retorna
#el valor sobre la tipificación del arreglo
# Out:
# El tipo de elementos que se contienen en la lista corresponden al tipo:  int32

# %%
#12.3 Usando una comprensión de lista, imprima el valor de cada elemento contenido en la
#lista dividido por 7

for i in range(len(a)):
    print(a[i], '/ 7 = ',a[i]/7 )
# Out:
# 0 / 7 =  0.0
# 27 / 7 =  3.857142857142857
# 54 / 7 =  7.714285714285714
# 81 / 7 =  11.571428571428571
# 108 / 7 =  15.428571428571429
# 135 / 7 =  19.285714285714285
# 162 / 7 =  23.142857142857142
# 189 / 7 =  27.0
# 216 / 7 =  30.857142857142858
# 243 / 7 =  34.714285714285715
# 270 / 7 =  38.57142857142857
# 297 / 7 =  42.42857142857143
# 324 / 7 =  46.285714285714285
# 351 / 7 =  50.142857142857146
# 378 / 7 =  54.0
# 405 / 7 =  57.857142857142854
# 432 / 7 =  61.714285714285715
# 459 / 7 =  65.57142857142857
# 486 / 7 =  69.42857142857143
# 513 / 7 =  73.28571428571429
# 540 / 7 =  77.14285714285714
# 567 / 7 =  81.0
# 594 / 7 =  84.85714285714286
# 621 / 7 =  88.71428571428571

# %%
#12.4 Cree un arreglo de numpy llamado ‘L’ a partir de la lista que contiene los datos del
#archivo, y asegúrese que los elementos contenidos sean de tipo “float32”. 

L = np.array(a,dtype='float32')
print('El tipo de elementos que se contienen en la lista corresponden al tipo (L): ',L.dtype)
print(L)
# Out:
# El tipo de elementos que se contienen en la lista corresponden al tipo (L):  float32
# [  0.  27.  54.  81. 108. 135. 162. 189. 216. 243. 270. 297. 324. 351.
#  378. 405. 432. 459. 486. 513. 540. 567. 594. 621.]

# %%
#12.5.a Ejecute los siguientes comandos;
L10 = 10 * L
print(L10)

#Esta instrucción demuestra la multiplicación de cada uno de los elementos de la lista por 10, retornando los 
#resultados posteriormente efectuados la multiplicación
# Out:
# [   0.  270.  540.  810. 1080. 1350. 1620. 1890. 2160. 2430. 2700. 2970.
#  3240. 3510. 3780. 4050. 4320. 4590. 4860. 5130. 5400. 5670. 5940. 6210.]

# %%
#12.5.b Ejecute los siguientes comandos;
L[24]

#Teniendo en cuenta que el recorrido de listas comienzan desde cero, la posición 24 no existe
#es por esto que en la ejecución de esta intrucción se sale de la lista
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-be940635da1a> in <module>
#       1 #12.5.b Ejecute los siguientes comandos;
# ----> 2 L[24]
#       3
#       4 #Teniendo en cuenta que el recorrido de listas comienzan desde cero, la posición 24 no existe
#       5 #es por esto que en la ejecución de esta intrucción se sale de la lista
#
# IndexError: index 24 is out of bounds for axis 0 with size 24

# %%
#12.5.c Ejecute los siguientes comandos;
L[-7]

#Esta instrucción posee el "recorrido" de atras hacia adelante, siendo este recorrido inverso, recorre la lista
#hasta que llegue a la posición -7 del arreglo en sentido invertido y obtiene el elemento de dicha posición
# Out:
# 459.0

# %%
#12.5.d Ejecute los siguientes comandos;
L[7]
#Esta intrucción trae el elemento de la lista de manera normal, implicando que retorne el elemento de lista en la posición 7
# Out:
# 189.0

# %%
#12.6 Muestre una tajada de 7 elementos contiguos dentro del arreglo L.
tajada = L[:7]
print(tajada)
# Out:
# [  0.  27.  54.  81. 108. 135. 162.]

# %%
#12.7. Muestre una selección de 5 elementos espaciados por dos elementos del arreglo L10.
#Use slicing para realizar la selección.
L10[0:15:3]
# Out:
# array([   0.,  810., 1620., 2430., 3240.], dtype=float32)

# %%
#12.8 Divida el valor de cada elemento del arreglo L10, por el valor correspondiente del
#arreglo L. No use bucles para realizar estas operaciones

L2 = L10/L
print(L2)
# Out:
# [nan 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10. 10.]
# <ipython-input-52-1e20a695b487>:4: RuntimeWarning: invalid value encountered in true_divide
#   L2 = L10/L

# %%
#10.9. Cambie permanentemente la geometría de los arreglos L y L10 a 3 filas y 8 columnas

L = np.reshape(L, (3,8)) 
print('L: \n',L,'\n')
L10 = np.reshape(L10, (3,8)) 
print('L10: \n',L10)
# Out:
# L:
#  [[  0.  27.  54.  81. 108. 135. 162. 189.]
#  [216. 243. 270. 297. 324. 351. 378. 405.]
#  [432. 459. 486. 513. 540. 567. 594. 621.]]
#
# L10:
#  [[   0.  270.  540.  810. 1080. 1350. 1620. 1890.]
#  [2160. 2430. 2700. 2970. 3240. 3510. 3780. 4050.]
#  [4320. 4590. 4860. 5130. 5400. 5670. 5940. 6210.]]

# %%
#12.10.a ¿Qué diferencia hay entre los resultados de L[2], L[2,] y L[2:]? Explique las
#diferencias
L[2]

#Este retorna la 2 fila de la matriz, tomando en cuenta que comienza desde 0
# Out:
# array([432., 459., 486., 513., 540., 567., 594., 621.], dtype=float32)

# %%
#12.10.b ¿Qué diferencia hay entre los resultados de L[2], L[2,] y L[2:]? Explique las
#diferencias
L[2,]

#Este retorna los elementas que pertenezcan a la posición 2 de la matriz, y los datos posteriores a esta posición
# Out:
# array([432., 459., 486., 513., 540., 567., 594., 621.], dtype=float32)

# %%
#12.10.c ¿Qué diferencia hay entre los resultados de L[2], L[2,] y L[2:]? Explique las
#diferencias
L[2:]

#
# Out:
# array([[432., 459., 486., 513., 540., 567., 594., 621.]], dtype=float32)

# %%
#12.11. Ejecute los siguientes comandos; muestre y explique sus resultados:
#a. Realice el producto cruz entre las matrices L y L10. Explique sus resultados.

ProductoCruz = L*L10
print('Producto cruz: \n', ProductoCruz)
# Out:
# Producto cruz:
#  [[      0.    7290.   29160.   65610.  116640.  182250.  262440.  357210.]
#  [ 466560.  590490.  729000.  882090. 1049760. 1232010. 1428840. 1640250.]
#  [1866240. 2106810. 2361960. 2631690. 2916000. 3214890. 3528360. 3856410.]]

# %%
#12.11. Ejecute los siguientes comandos; muestre y explique sus resultados:
#b. Realice el producto punto entre las matrices L y L10. Explique sus resultados.
from numpy import array
ProductoPunto = np.dot(L,L10.T)
print('Producto punto: \n', ProductoPunto)
# Out:
# Producto punto:
#  [[ 1020600.  2653560.  4286520.]
#  [ 2653560.  8019000. 13384440.]
#  [ 4286520. 13384440. 22482360.]]

# %%
#12.12 Realice una comparación de igualdad entre L y L10, y guarde la matriz Booleana como
#la variable COMP.

COMP = L == L10
print(COMP)
# Out:
# [[ True False False False False False False False]
#  [False False False False False False False False]
#  [False False False False False False False False]]

# %%
#12.13. Realice una comparación 7*L < L10, y guarde sus resultados en una matriz Booleana
#como la variable COMP2

COMP2 =  (7*L < L10)
print(COMP2)
# Out:
# [[False  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]]

# %%
#12.14.a Imprima los resultados de las siguiente instrucciones, y explique por qué obtiene cada
#resultado:
COMP.all()
# Out:
# False

# %%
#12.14.b Imprima los resultados de las siguiente instrucciones, y explique por qué obtiene cada
#resultado:
COMP.any()
# Out:
# True

# %%
#12.15. Realice la operación lógica OR entre la matriz COMP negada y la matriz COMP2; guarde
#su resultante matriz Booleana como la variable ResOR.
ResOr = ~COMP | COMP2
print(ResOr)
# Out:
# [[False  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]]

# %%
#16. Aplique la matriz ResOR como máscara sobre la matriz L10, y guarde su resultado
#como la variable X
X = L10[ResOr]
print(X)
# Out:
# [ 270.  540.  810. 1080. 1350. 1620. 1890. 2160. 2430. 2700. 2970. 3240.
#  3510. 3780. 4050. 4320. 4590. 4860. 5130. 5400. 5670. 5940. 6210.]

# %% [markdown]
# #### I. ¿Cómo cree usted que el método científico puede conllevar al descubrimiento de conocimiento, o ser aplicado para la toma de mejores decisiones, mediante el uso de herramientas computacionales como Python y Jupyter Notebooks? Desarrolle su respuesta de forma lógica y consecuente. En lo posible plantee un ejemplo hipotético, basado en su propia experiencia, para explicar su respuesta

# %% [markdown]
# La metodología científica permite obtener conocimiento a partir de la observación del entorno sistémico, el entendimiento de sus partes y su funcionamiento como un todo a través de la medición, experimentación, análisis y formulación de hipótesis; teniendo en cuenta lo anterior, se facilita la toma de decisiones que sean favorables al tener un mapeo de toda la situación problemática a solucionar. Con el uso de ese mapeo y compresión de toda la situación problemática, es posible planear, diseñar, desarrollar, probar y corregir una solución de software implementada en el lenguaje de programación Python junto con la herramienta de ambiente de trabajo Jupyter Notebook que nos proporciona un entorno para el flujo de datos, su depuración, la simulación numérica y la codificación para el manejo de todos esos datos obtenidos de nuestra observación y análisis sistémico problemático.
#
# Tomando todo lo anterior y aplicándolo a un ejemplo hipotético, es posible plantear el uso de la metodología científica para el análisis sistémico del sistema de salud e implementar una solución de software a la problemática que se ha venido presentando respecto a la aplicación de la vacuna contra el Covid-19 en donde se evidencia una falta de agilidad en la administración del biológico para el personal médico y mayores de 80 años estipulados en la primera fase de vacunación por el gobierno colombiano; además de la presentación de personas que interfieren en ese proceso al recibir la vacuna y no pertenecer a la primera fase. Esa solución de software en Python permitiría visualizar un informe en tiempo real de las personas que fueron vacunadas, las personas que faltan por vacunar, lugares de vacunación, datos del vacunador, personas que aún no reciben las dosis, vacunas disponibles, zonas de almacenamiento de las dosis, una captura de imagen del procedimiento realizado por el vacunador; todos esos datos podrían ser manejados por Jupyter Notebook.

# %% [markdown]
# #### 17. Escriba el objeto X como un archivo de tipo binario, y nómbrelo de la siguiente manera:
# “apellido_nombre_parcial1.pickle”. Adjunte este archivo a la entrega de
# este examen.

# %%
import pickle
with open("C:/Users/ASUS X542U/Desktop/Espacio de trabajo/Vargas_Daniel_parcial1.pickle", "wb") as a:
    pickle.dump(X,a)

# %%
parcial = open("C:/Users/ASUS X542U/Desktop/Espacio de trabajo/Vargas_Daniel_parcial1.pickle",'rb') 
leer = pickle.load(parcial)
print("Se carga el archivo .pickel y retornamos el resultado: \n")
print(leer)
# Out:
# Se carga el archivo .pickel y retornamos el resultado:
#
# [ 270.  540.  810. 1080. 1350. 1620. 1890. 2160. 2430. 2700. 2970. 3240.
#  3510. 3780. 4050. 4320. 4590. 4860. 5130. 5400. 5670. 5940. 6210.]
